# %% [markdown]
# # Test Re-prioritization in Continuous Testing Environment

# %% [markdown]
# ### Reading and converting GooglePresCleanData and GooglePostCleanData files to csv files

# %%
#Convert GooglePre dataset to csv files
import csv

with open('C:\Software testingpapers\SOEN-7481-Project-master\GooglePresCleanData.out', 'r') as in_file, open('C:\Software testingpapers\SOEN-7481-Project-master\GooglePresCleanData.csv', 'w') as out_file:
    stripped = (line.strip() for line in in_file)
    splited_lines = (line.split(",") for line in stripped)
    grouped_data = zip(splited_lines)
    writer = csv.writer(out_file)
    writer.writerow(("Test_Suite","Change_Request","Stage","Status","Launch_Time","Execution_Time","Size",
            "Shard_number","Run_number","Language"))
    for singleLine in grouped_data:
        writer.writerows(singleLine)

# %%
#Convert GooglePost dataset to csv files
import csv
import itertools
with open('C:\Software testingpapers\SOEN-7481-Project-master\GooglePostCleanData.out', 'r') as in_file, open('C:\Software testingpapers\SOEN-7481-Project-master\GooglePostCleanData.csv', 'w') as out_file:
    stripped = (line.strip() for line in in_file)
    splited_lines = (line.split(",") for line in stripped)
    grouped_data = zip(splited_lines)
    writer = csv.writer(out_file)
    writer.writerow(("Test_Suite","Change_Request","Stage","Status","Launch_Time","Execution_Time","Size",
            "Shard_number","Run_number","Language"))
    for singleLine in grouped_data:
        writer.writerows(singleLine)

# %%
# reading and storing GooglePredataset 

import numpy as np
import pandas as pd

googleprecommit=pd.read_csv('C:\Software testingpapers\SOEN-7481-Project-master\GooglePresCleanData.csv') 
googleprecommit
# Out:
#                                                 Test_Suite  Change_Request  \
# 0        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 1        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 2        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 3        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 4        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 5        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 6        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 7        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 8        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 9        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 10       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 11       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 12       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 13       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 14       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 15       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 16       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 17       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 18       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 19       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 20       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 21       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 22       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 23       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 24       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 25       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 26       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 27       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 28       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 29       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# ...                                                    ...             ...
# 1045593  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045594  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045595  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045596  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045597  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045598  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045599  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045600  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045601  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045602  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045603  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045604  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6052
# 1045605  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6054
# 1045606  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6054
# 1045607  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6054
# 1045608  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6054
# 1045609  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6054
# 1045610  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6054
# 1045611  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045612  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045613  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045614  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045615  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045616  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045617  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045618  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045619  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045620  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6056
# 1045621  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6056
# 1045622  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6056
#
#         Stage  Status              Launch_Time  Execution_Time    Size  \
# 0        pres  PASSED    2014-01-01 00:48:24.0           218.0   SMALL
# 1        pres  PASSED  2014-01-01 00:48:24.218           133.0   SMALL
# 2        pres  PASSED  2014-01-01 00:48:24.351           199.0  MEDIUM
# 3        pres  PASSED   2014-01-01 00:48:24.55           284.0   SMALL
# 4        pres  PASSED  2014-01-01 00:48:24.834           152.0   SMALL
# 5        pres  PASSED  2014-01-01 00:48:24.986           210.0   SMALL
# 6        pres  PASSED  2014-01-01 00:48:25.196           171.0   SMALL
# 7        pres  PASSED  2014-01-01 00:48:25.367           313.0   SMALL
# 8        pres  PASSED   2014-01-01 00:48:25.68           371.0   SMALL
# 9        pres  PASSED  2014-01-01 00:48:26.051           454.0   SMALL
# 10       pres  PASSED  2014-01-01 00:48:26.505           569.0   SMALL
# 11       pres  PASSED  2014-01-01 00:48:27.074           623.0   SMALL
# 12       pres  PASSED  2014-01-01 00:48:27.697           455.0   SMALL
# 13       pres  PASSED  2014-01-01 00:48:28.152           731.0   SMALL
# 14       pres  PASSED  2014-01-01 00:48:28.883          1032.0   SMALL
# 15       pres  PASSED  2014-01-01 00:48:29.915           837.0   SMALL
# 16       pres  PASSED  2014-01-01 00:48:30.752          1984.0   SMALL
# 17       pres  PASSED  2014-01-01 00:48:32.736           667.0   SMALL
# 18       pres  PASSED  2014-01-01 00:48:33.403          4840.0  MEDIUM
# 19       pres  PASSED  2014-01-01 00:48:38.243          1508.0   SMALL
# 20       pres  PASSED  2014-01-01 00:48:39.751         36377.0   LARGE
# 21       pres  PASSED  2014-01-01 00:49:16.128          2659.0   SMALL
# 22       pres  PASSED  2014-01-01 00:49:18.787          1905.0   SMALL
# 23       pres  PASSED  2014-01-01 00:49:20.692          1746.0   SMALL
# 24       pres  PASSED  2014-01-01 00:49:22.438          2009.0   SMALL
# 25       pres  PASSED  2014-01-01 00:49:24.447          2987.0   SMALL
# 26       pres  PASSED  2014-01-01 00:49:27.434          1586.0   SMALL
# 27       pres  PASSED   2014-01-01 00:49:29.02          1677.0   SMALL
# 28       pres  PASSED  2014-01-01 00:49:30.697          1553.0   SMALL
# 29       pres  PASSED   2014-01-01 00:49:32.25          2615.0   SMALL
# ...       ...     ...                      ...             ...     ...
# 1045593  pres  PASSED  2014-01-15 16:55:58.555           687.0   LARGE
# 1045594  pres  PASSED  2014-01-15 16:55:59.242           785.0   LARGE
# 1045595  pres  PASSED  2014-01-15 16:56:00.027           427.0  MEDIUM
# 1045596  pres  PASSED  2014-01-15 16:56:00.454          1699.0   LARGE
# 1045597  pres  PASSED  2014-01-15 16:56:02.153          1615.0   LARGE
# 1045598  pres  PASSED  2014-01-15 16:56:03.768          1149.0   LARGE
# 1045599  pres  PASSED  2014-01-15 16:56:04.917           157.0   SMALL
# 1045600  pres  PASSED  2014-01-15 16:56:05.074           695.0   LARGE
# 1045601  pres  PASSED  2014-01-15 16:56:05.769           892.0   LARGE
# 1045602  pres  PASSED  2014-01-15 16:56:06.661           917.0   LARGE
# 1045603  pres  PASSED  2014-01-15 16:56:07.578           827.0   LARGE
# 1045604  pres  PASSED  2014-01-15 16:56:08.405           733.0   LARGE
# 1045605  pres  PASSED    2014-01-15 16:55:20.0         10414.0   LARGE
# 1045606  pres  PASSED  2014-01-15 16:55:30.414          9522.0   LARGE
# 1045607  pres  PASSED  2014-01-15 16:55:39.936          9248.0   LARGE
# 1045608  pres  PASSED  2014-01-15 16:55:49.184         11175.0   LARGE
# 1045609  pres  PASSED  2014-01-15 16:56:00.359         13958.0   LARGE
# 1045610  pres  PASSED  2014-01-15 16:56:14.317         10439.0   LARGE
# 1045611  pres  PASSED    2014-01-15 16:56:54.0           522.0   SMALL
# 1045612  pres  PASSED  2014-01-15 16:56:54.522           860.0  MEDIUM
# 1045613  pres  PASSED  2014-01-15 16:56:55.382           477.0   SMALL
# 1045614  pres  PASSED  2014-01-15 16:56:55.859           297.0   SMALL
# 1045615  pres  PASSED  2014-01-15 16:56:56.156           559.0  MEDIUM
# 1045616  pres  PASSED  2014-01-15 16:56:56.715           340.0   SMALL
# 1045617  pres  PASSED  2014-01-15 16:56:57.055           441.0   SMALL
# 1045618  pres  PASSED  2014-01-15 16:56:57.496           557.0   SMALL
# 1045619  pres  PASSED  2014-01-15 16:56:58.053          1168.0  MEDIUM
# 1045620  pres  PASSED    2014-01-15 16:57:44.0          3360.0  MEDIUM
# 1045621  pres  PASSED   2014-01-15 16:57:47.36         13824.0  MEDIUM
# 1045622  pres  PASSED  2014-01-15 16:58:01.184          3360.0  MEDIUM
#
#          Shard_number  Run_number Language
# 0                   0           0       CC
# 1                   0           0       CC
# 2                   0           0       CC
# 3                   0           0       CC
# 4                   0           0       CC
# 5                   0           0       CC
# 6                   0           0       CC
# 7                   0           0       CC
# 8                   0           0       CC
# 9                   0           0       CC
# 10                  0           0       CC
# 11                  0           0       CC
# 12                  0           0       CC
# 13                  0           0       CC
# 14                  0           0       CC
# 15                  0           0       CC
# 16                  0           0       CC
# 17                  0           0       CC
# 18                  0           0       CC
# 19                  0           0       CC
# 20                  0           0       CC
# 21                  0           0       CC
# 22                  0           0       CC
# 23                  0           0       CC
# 24                  0           0       CC
# 25                  0           0       CC
# 26                  0           0       CC
# 27                  0           0       CC
# 28                  0           0       CC
# 29                  0           0       CC
# ...               ...         ...      ...
# 1045593             0           0      WEB
# 1045594             0           0      WEB
# 1045595             0           0       SH
# 1045596             0           0      WEB
# 1045597             0           0      WEB
# 1045598             0           0      WEB
# 1045599             0           0     JAVA
# 1045600             0           0      WEB
# 1045601             0           0      WEB
# 1045602             0           0      WEB
# 1045603             0           0      WEB
# 1045604             0           0      WEB
# 1045605             0           0      WEB
# 1045606             0           0      WEB
# 1045607             0           0      WEB
# 1045608             0           0      WEB
# 1045609             0           0      WEB
# 1045610             0           0      WEB
# 1045611             0           0       CC
# 1045612             0           0       CC
# 1045613             0           0       CC
# 1045614             0           0       CC
# 1045615             0           0       CC
# 1045616             0           0       CC
# 1045617             0           0       CC
# 1045618             0           0       CC
# 1045619             0           0       CC
# 1045620             0           0       CC
# 1045621             0           0       CC
# 1045622             0           0       CC
#
# [1045623 rows x 10 columns]

# %%
# function to return postclean data
def getPostData():
    googlepostcommit=pd.read_csv('C:\Software testingpapers\SOEN-7481-Project-master\GooglePostCleanData.csv') 
    googlepostcommit
    return googlepostcommit

# %%
# reading and storing GooglePredataset ;  googlepostCommit it contains post clean data

import numpy as np
import pandas as pd

googlepostcommit=getPostData()
googlepostcommit
# Out:
#                                                 Test_Suite  Change_Request  \
# 0        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 1        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 2        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 3        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 4        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 5        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 6        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 7        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 8        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 9        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 10       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 11       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 12       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 13       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 14       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 15       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 16       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 17       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 18       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 19       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 20       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 21       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 22       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 23       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 24       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 25       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 26       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 27       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 28       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 29       /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# ...                                                    ...             ...
# 1461273  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461274  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461275  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461276  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461277  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461278  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461279  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461280  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461281  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461282  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461283  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461284  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461285  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461286  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461287  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461288  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461289  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461290  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461291  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461292  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461293  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461294  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461295  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6057
# 1461296  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
# 1461297  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
# 1461298  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
# 1461299  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
# 1461300  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
# 1461301  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
# 1461302  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
#
#         Stage  Status              Launch_Time  Execution_Time    Size  \
# 0        post  PASSED    2014-01-01 00:00:02.0           996.0   LARGE
# 1        post  PASSED  2014-01-01 00:00:02.996          1676.0   LARGE
# 2        post  PASSED  2014-01-01 00:00:04.672          2565.0   LARGE
# 3        post  PASSED  2014-01-01 00:00:07.237          1611.0   LARGE
# 4        post  PASSED  2014-01-01 00:00:08.848          1089.0   LARGE
# 5        post  PASSED  2014-01-01 00:00:09.937          1408.0   SMALL
# 6        post  PASSED  2014-01-01 00:00:11.345            41.0   SMALL
# 7        post  PASSED  2014-01-01 00:00:11.386           510.0   SMALL
# 8        post  PASSED  2014-01-01 00:00:11.896           247.0  MEDIUM
# 9        post  PASSED  2014-01-01 00:00:12.143           447.0   SMALL
# 10       post  PASSED   2014-01-01 00:00:12.59          1082.0  MEDIUM
# 11       post  PASSED  2014-01-01 00:00:13.672           100.0   SMALL
# 12       post  PASSED  2014-01-01 00:00:13.772           521.0   SMALL
# 13       post  PASSED  2014-01-01 00:00:14.293          2248.0  MEDIUM
# 14       post  PASSED  2014-01-01 00:00:16.541           367.0   SMALL
# 15       post  PASSED  2014-01-01 00:00:16.908          2620.0   SMALL
# 16       post  PASSED  2014-01-01 00:00:19.528           651.0   SMALL
# 17       post  PASSED  2014-01-01 00:00:20.179            39.0   SMALL
# 18       post  PASSED  2014-01-01 00:00:20.218           185.0   SMALL
# 19       post  PASSED  2014-01-01 00:00:20.403          1163.0  MEDIUM
# 20       post  PASSED  2014-01-01 00:00:21.566          1440.0   LARGE
# 21       post  PASSED  2014-01-01 00:00:23.006           909.0  MEDIUM
# 22       post  PASSED  2014-01-01 00:00:23.915           100.0   LARGE
# 23       post  PASSED  2014-01-01 00:00:24.015           114.0  MEDIUM
# 24       post  PASSED  2014-01-01 00:00:24.129           146.0   SMALL
# 25       post  PASSED  2014-01-01 00:00:24.275           143.0  MEDIUM
# 26       post  PASSED  2014-01-01 00:00:24.418           136.0  MEDIUM
# 27       post  PASSED  2014-01-01 00:00:24.554            93.0  MEDIUM
# 28       post  PASSED  2014-01-01 00:00:24.647          1248.0  MEDIUM
# 29       post  PASSED  2014-01-01 00:00:25.895            18.0   SMALL
# ...       ...     ...                      ...             ...     ...
# 1461273  post  PASSED  2014-01-15 17:01:07.075          4623.0   LARGE
# 1461274  post  PASSED  2014-01-15 17:01:11.698          2896.0   LARGE
# 1461275  post  PASSED  2014-01-15 17:01:14.594          3706.0   LARGE
# 1461276  post  PASSED    2014-01-15 17:01:18.3          1752.0   LARGE
# 1461277  post  PASSED  2014-01-15 17:01:20.052          3789.0   LARGE
# 1461278  post  PASSED  2014-01-15 17:01:23.841          2303.0   LARGE
# 1461279  post  PASSED  2014-01-15 17:01:26.144          1642.0   LARGE
# 1461280  post  PASSED  2014-01-15 17:01:27.786          2086.0   LARGE
# 1461295             0           0       SH
# 1461296             0           0     JAVA
# 1461297             0           0     JAVA
# 1461298             0           0     JAVA
# 1461299             0           0     JAVA
# 1461300             1           0     JAVA
# 1461301             0           0     JAVA
# 1461302             0           0     JAVA
#
# [1461303 rows x 10 columns]

# %%
# function for calculating pass fail rate
def CalculateRate(passFailCount):
    value=(passFailCount/(passFailCount.sum()))*100
    return value

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Success and Failure rate by change request number

# %%
# This gives pass fail test status according to changerequest It uses google post data

postTotalPassFail_rate = googlepostcommit.groupby('Change_Request')['Status'].value_counts() 
postTotalPassFail_rate.groupby(level=0).apply(CalculateRate)
# Out:
# Change_Request  Status
# 0               PASSED     99.816850
#                 FAILED      0.183150
# 1               PASSED    100.000000
# 2               PASSED    100.000000
# 3               PASSED     98.963731
#                 FAILED      1.036269
# 4               PASSED    100.000000
# 6               PASSED    100.000000
# 7               PASSED    100.000000
# 8               PASSED    100.000000
# 9               PASSED    100.000000
# 10              PASSED     97.457627
#                 FAILED      2.542373
# 11              PASSED    100.000000
# 12              PASSED    100.000000
# 13              PASSED     94.444444
#                 FAILED      5.555556
# 14              PASSED     99.633968
#                 FAILED      0.366032
# 15              PASSED    100.000000
# 16              PASSED    100.000000
# 17              PASSED    100.000000
# 18              PASSED    100.000000
# 19              PASSED    100.000000
# 20              PASSED    100.000000
# 21              PASSED    100.000000
# 22              PASSED    100.000000
# 23              PASSED    100.000000
# 24              PASSED    100.000000
# 25              PASSED    100.000000
#                              ...
# 6024            PASSED    100.000000
# 6025            PASSED    100.000000
# 6027            PASSED    100.000000
# 6029            PASSED     99.942230
#                 FAILED      0.057770
# 6033            PASSED     99.641577
#                 FAILED      0.358423
# 6034            PASSED    100.000000
# 6035            PASSED    100.000000
# 6036            PASSED    100.000000
# 6037            PASSED    100.000000
# 6038            PASSED    100.000000
# 6039            PASSED    100.000000
# 6040            PASSED    100.000000
# 6041            PASSED    100.000000
# 6042            PASSED    100.000000
# 6043            PASSED     99.813259
#                 FAILED      0.186741
# 6045            PASSED    100.000000
# 6046            PASSED    100.000000
# 6047            PASSED    100.000000
# 6048            PASSED    100.000000
# 6049            PASSED     98.159509
#                 FAILED      1.840491
# 6050            PASSED     99.290780
#                 FAILED      0.709220
# 6051            PASSED    100.000000
# 6053            PASSED    100.000000
# 6057            PASSED    100.000000
# 6058            PASSED    100.000000
# Name: Status, Length: 5443, dtype: float64

# %%
#Number of passed and failed tests by change request number for GooglePre Dataset

preTotalPassFail_rate = googleprecommit.groupby('Change_Request')['Status'].value_counts() 
preTotalPassFail_rate.groupby(level=0).apply(CalculateRate)
# Out:
# Change_Request  Status
# 5               PASSED    100.000000
# 63              PASSED    100.000000
# 86              PASSED    100.000000
# 87              PASSED    100.000000
# 92              PASSED    100.000000
# 103             PASSED    100.000000
# 106             PASSED     97.413793
#                 FAILED      2.586207
# 107             PASSED    100.000000
# 122             PASSED    100.000000
# 123             PASSED     99.769408
#                 FAILED      0.230592
# 124             PASSED    100.000000
# 125             PASSED    100.000000
# 129             PASSED    100.000000
# 130             PASSED    100.000000
# 133             PASSED    100.000000
# 136             PASSED    100.000000
# 137             PASSED    100.000000
# 140             PASSED    100.000000
# 146             PASSED    100.000000
# 151             PASSED     99.820628
#                 FAILED      0.179372
# 152             PASSED    100.000000
# 153             PASSED    100.000000
# 155             PASSED     99.456522
#                 FAILED      0.543478
# 159             PASSED    100.000000
# 161             PASSED    100.000000
# 164             PASSED    100.000000
#                              ...
# 5968            PASSED    100.000000
# 5977            PASSED    100.000000
# 5981            PASSED     96.551724
#                 FAILED      3.448276
# 5983            PASSED    100.000000
# 5984            PASSED    100.000000
# 5986            PASSED    100.000000
# 5988            PASSED    100.000000
# 5994            PASSED    100.000000
# 5995            PASSED    100.000000
# 5998            PASSED    100.000000
# 6002            PASSED    100.000000
# 6005            PASSED    100.000000
# 6007            PASSED    100.000000
# 6008            PASSED    100.000000
# 6011            PASSED    100.000000
# 6017            PASSED    100.000000
# 6019            PASSED    100.000000
# 6022            PASSED    100.000000
# 6026            PASSED    100.000000
# 6028            PASSED    100.000000
# 6030            PASSED    100.000000
# 6031            PASSED    100.000000
# 6032            PASSED    100.000000
# 6044            PASSED    100.000000
# 6052            PASSED     99.447514
#                 FAILED      0.552486
# 6054            PASSED    100.000000
# 6055            PASSED    100.000000
# 6056            PASSED    100.000000
# Name: Status, Length: 1903, dtype: float64

# %%
# Number of change requests per minute in GooglePre
# Maximum number of change requests per minute in GooglePre
# Median of number of change requests per minute in GooglePre

googleprecommit['Launch_Time'] = pd.to_datetime(googleprecommit['Launch_Time'])
pre_unique_change_request = googleprecommit.groupby(pd.Grouper(key='Launch_Time', freq='min'))['Change_Request'].apply(pd.Series.nunique)

print("pre_unique_change_requests")
print("Median: "+str(pre_unique_change_request.median()))
print("Maximum: "+str(pre_unique_change_request.max()))
# Out:
# pre_unique_change_requests
# Median: 1.0
# Maximum: 10

# %%
# Number of test requests per minute in GooglePre
# Maximum number of test requests per minute in GooglePre
# Median of number of test requests per minute in GooglePre

googleprecommit['Launch_Time'] = pd.to_datetime(googleprecommit['Launch_Time'])
pre_unique_test_request = googleprecommit.groupby(pd.Grouper(key='Launch_Time', freq='min'))['Test_Suite'].apply(pd.Series.nunique)

print("pre_unique_test_requests")
print("Median: "+str(pre_unique_test_request.median()))
print("Maximum: "+str(pre_unique_test_request.max()))
# Out:
# pre_unique_test_requests
# Median: 6.0
# Maximum: 2102

# %%
# Number of change requests per minute in GooglePost
# Maximum number of change requests per minute in GooglePost
# Median of number of change requests per minute in GooglePost

googlepostcommit['Launch_Time'] = pd.to_datetime(googlepostcommit['Launch_Time'])
post_unique_change_req = googlepostcommit.groupby(pd.Grouper(key='Launch_Time', freq='min'))['Change_Request'].apply(pd.Series.nunique)

print("post_unique_change_req")
print("Median: "+str(post_unique_change_req.median()))
print("Maximum: "+str(post_unique_change_req.max()))
# Out:
# post_unique_change_req
# Median: 2.0
# Maximum: 27

# %%
# Number of test requests per minute in GooglePost
# Maximum number of test requests per minute in GooglePost
# Median of number of test requests per minute in GooglePost

googlepostcommit['Launch_Time'] = pd.to_datetime(googlepostcommit['Launch_Time'])
post_unique_test_req = googlepostcommit.groupby(pd.Grouper(key='Launch_Time', freq='min'))['Test_Suite'].apply(pd.Series.nunique)

print("post_unique_test_req")
print("Median: "+str(post_unique_test_req.median()))
print("Maximum: "+str(post_unique_test_req.max()))
# Out:
# post_unique_test_req
# Median: 19.0
# Maximum: 2560

# %% [markdown]
# ### Graph Plots

# %%
# Number of change requests per minute box plot for GooglePre Dataset

import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot( y=pre_unique_change_request)

# %%
# Number of test requests per minute box plot for GooglePre Dataset

import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot( y=pre_unique_test_request)

# %% [markdown]
# ## Algorithm Implementation

# %% [markdown]
# ### Re prioritization Algorithm

# %% [markdown]
#  Calculate conditional probability for incoming test cases and calculate new priority score accordingly.
#
#   - Inputs (test to be reprioritized(currentTest),recently finished test from the same change request(t_finish),test execution     history,dispatch_queue)
#   - check if the test already exists in history.
#   - if no, ie it is a new test, then set its conditional failure rate to 0.5 and add it to dispatch queue
#   - if yes, find the following co failure parameters with respect to current test and recently finished test
#       + co-occurance count
#       + co-fail count
#       + t_fail , t_finish pass count
#   - if previous test status= failed
#        - new score= previous priority+ (p(current and previous test fails)- 0.5)
#   - if previous test status= pass
#       - new score= previous priority+ (p(current test fails and previous test pass)-0.5)
#   - priorirty  = previous_priority+(new score-0.5)

# %%
# define a dataset to store frequent co failing test suites
Cofailure_Distribution = pd.DataFrame(columns = ["Test Pair","Fail Together","Run Together","Pass-Fail"])

# %%
import traceback
#currentTest - test to be reprioritized
#t_finish - historial tests with same change request( To calculate co-fail data)
#finishedGpost - historical completed tests (To calculate the new priority)

def reprioritize(currentTest,index,t_finish,finishedGpost,dispatch_queue): 
    global Cofailure_Distribution
    test_names = [currentTest.Test_Suite,t_finish.Test_Suite]
    sorted_names = sorted(test_names)
    joined_names = ','.join(sorted_names)
    
    # get all change request numbers
    change_requests= googlepostcommit.Change_Request.unique() #[   5   63   86 ... 6054 6055 6056]

    # check if currentTest was executed before in the historical queue
    if (currentTest.Test_Suite in finishedGpost.Test_Suite.values):
        # print("Test was executed before")
        # initialise the co-fail count
        co_fail_count=0
        # initialise current fail , t_finish pass count
        co_fail_pass_count=0
        # initialise co_occurance count
        co_occurance_count=0

    
        # get the previous status
        previous_status=finishedGpost.iat[finishedGpost.Test_Suite.eq(currentTest.Test_Suite).idxmax(),3]
        #get the previous priority off currentTest
        previous_priority=finishedGpost.iat[finishedGpost.Test_Suite.eq(currentTest.Test_Suite).idxmax(),10] # priority column no=10
        
        # get all change requests before the current test change request .
        # Generate co fail/co occurance data of currentTest with respect to other tests in these change requests.
        previous_change_requests= sorted(i for i in change_requests if i < currentTest.Change_Request)
        
        # COFAILURE DISTRIBUTION USING CONDITIONAL PROBABILITY
        # iterate through the previous change requests
        for i in range(0, len(previous_change_requests)):
            prev_req = previous_change_requests[i]
            overlapping_row_count = googlepostcommit[googlepostcommit['Change_Request']<prev_req].shape[0]       
            # get all test suites in current change request being iterated
            test_suites_in_change_req=googlepostcommit[googlepostcommit['Change_Request']==prev_req]                       
            try:
                # check for co-occurance
                if(currentTest.Test_Suite in test_suites_in_change_req.Test_Suite.values and t_finish.Test_Suite in test_suites_in_change_req.Test_Suite.values):
                    # if yes, increment the co-occurance count
                    co_occurance_count+=1
                    test_suite_actual_index_currentTest = test_suites_in_change_req.Test_Suite.eq(currentTest.Test_Suite).idxmax()
                    test_suite_actual_index_tFinish = test_suites_in_change_req.Test_Suite.eq(t_finish.Test_Suite).idxmax()
                    current_test_previous_status=test_suites_in_change_req.iat[test_suite_actual_index_currentTest-overlapping_row_count,3]
                    # get the status of currentTest in pre_req
                    t_finish_previous_status=test_suites_in_change_req.iat[test_suite_actual_index_tFinish-overlapping_row_count,3]
                    #  current_test failed and t_finish also failed
                    if(current_test_previous_status == "FAILED" and t_finish_previous_status == "FAILED"):
                        # increment the co fail count
                        co_fail_count+=1
                    # if current test failed and t_finish passed
                    if(current_test_previous_status == "FAILED" and t_finish_previous_status == "PASSED"):
                        # increment the count of fail and pass together
                        co_fail_pass_count+=1

            except:
                print("Exception Occured")
                print("Shape of test suite in change req ",test_suites_in_change_req.shape)
                traceback.print_exc()
                pass
                
            
        #Assign conditional probability score  
        conditional_prob_score=0
     
        # if both currentTest and t_finish fails
        #if(previous_status=="FAILED"):
        if t_finish.Status == "FAILED":
            # conditional probability= no of time both fail together/ no of times both occur together
            if co_occurance_count != 0:
                conditional_prob_score=co_fail_count/co_occurance_count

        else:
            # if currentTest fail and t_finish pass
            if co_occurance_count != 0:
                conditional_prob_score=co_fail_pass_count/co_occurance_count
           
        if(conditional_prob_score!=0):
            new_score=previous_priority+(conditional_prob_score-0.5)
            finishedGpost.loc[finishedGpost['Test_Suite'] == currentTest.Test_Suite, 'Priority'] = new_score
            dispatch_queue.at[index, 'Priority'] = new_score

        # if the current test or previous test has status as failed, change the status as failed in history .
        # if the test is already present in history , a new row will not be added for that test suite again.
        # So update the status of existing row.
        
        if(previous_status == "FAILED" or currentTest.Status == "FAILED"):
            finishedGpost.loc[finishedGpost['Test_Suite'] == currentTest.Test_Suite, 'Status'] = "Failed"

        Cofailure_Distribution = Cofailure_Distribution.append({"Test Pair" : joined_names, "Fail Together" : co_fail_count, "Run Together" : co_occurance_count ,"Pass-Fail" : co_fail_pass_count}, ignore_index=True)
        return True
# if the test case is a new test case 
    else:
        #print("Test case not present in history . Should be appended.")
        return False

# %%
#function to assign probablity according to status
def calculateProbabilityPassFail(status): 
    value=1
    if status=="PASSED":
        value=0.5
    return value

# %%
#function to append processed data to history dataset
def appendingToHistory(row,finishedGpost):
        #print("appending")
        #priority=calculateProbabilityPassFail(row['Status'])
        priority=0.5
        finishedGpost=finishedGpost.append({'Test_Suite' : row.Test_Suite , 'Change_Request' : row.Change_Request, 
                                                'Stage':row.Stage, 'Status': row.Status, 'Launch_Time':row.Launch_Time, 
                                                      'Execution_Time':row.Execution_Time, 'Size':row.size, 'Shard_number':row.Shard_number,
                                                      'Run_number':row.Run_number, 'Language':row.Language,
                                              'Priority':priority}, ignore_index=True)
        
        return finishedGpost

# %%
def addtoDispatchQueue(row,dispatch_queue):
        #print("appending")
        #priority=calculateProbabilityPassFail(row['Status'])
        priority=0.5
        dispatch_queue =dispatch_queue.append({'Test_Suite' : row.Test_Suite , 'Change_Request' : row.Change_Request, 
                                                'Stage':row.Stage, 'Status': row.Status, 'Launch_Time':row.Launch_Time, 
                                                      'Execution_Time':row.Execution_Time, 'Size':row.size, 'Shard_number':row.Shard_number,
                                                      'Run_number':row.Run_number, 'Language':row.Language,
                                              'Priority':priority}, ignore_index=True)
        
        return dispatch_queue

# %%
#function t set priority to first change request and set it as history dataset
import pandas as pd
def settingPriority(data): 
    googlepostcommitdata=data
    googlepost_finished = pd.DataFrame(googlepostcommitdata[googlepostcommitdata['Change_Request']==0]) 
    googlepost_finished['Priority'] = 0.5
    #googlepost_finished = pd.DataFrame(googlepostcommitdata[0:200]) 
    '''checkingPassStatus=(googlepost_finished['Status']=="PASSED")
    googlepost_finished['Priority'] = googlepost_finished['Status'].mask(checkingPassStatus, 0.5 )
    updatingFailStatus=(googlepost_finished['Priority']!=0.5)
    googlepost_finished['Priority'] = googlepost_finished['Priority'].mask(updatingFailStatus,1)'''
    return googlepost_finished

# %% [markdown]
# ### CodynaqSingle Algorithm

# %%
# create historical data frame= newgooglepre - eg. change req =5

# waiting queue= googlepreremoved= all change requests except 5

def codynaqsingle(googlepostdatas,finishedGpost,googlepost_rem,dispatch_queue):
        
    
    # iterate through waiting queue for reprioritization (row= test case to be reprioritized)
    for index, row in googlepost_rem.iterrows():
        # check if the previous test case and the current test case are from the same change request. 
        # Because the algorithm will be applied only if t1, t2 are in the same test request
        if googlepostdatas.loc[index, 'Change_Request'] == googlepostdatas.loc[index-1, 'Change_Request']:
            # get all the test cases from historical data set (newgooglepre) of current change request
            temp_test_suites_current_request= finishedGpost.loc[finishedGpost['Change_Request']==row.Change_Request] 
            # iterate through the historic test cases from the same change request for reprioritizing the current test case
            for index_j, row_j in temp_test_suites_current_request.iterrows():
                # temp suite can contain the same test case from historical result with same change request number
                #finishedGpost can contain the same test case from historical results with any change request
                result=reprioritize(row,index,row_j, finishedGpost,dispatch_queue)
                #print(index," : ",index_j," : ",row.Change_Request," : ",row_j.Change_Request)
                if(result==False):
                    finishedGpost=appendingToHistory(row,finishedGpost)
                    #dispatch_queue = addtoDispatchQueue(row,dispatch_queue)
                    #print("append success :)")
        else:
            # append the test case to the historical data frame that has stores the tests that has finished execution
            finishedGpost=appendingToHistory(row,finishedGpost)
            #dispatch_queue = addtoDispatchQueue(row,dispatch_queue)
    
            
    return [finishedGpost,dispatch_queue]

# %%
#googlepost=googlepost[0:10000]
googlepostcommit=getPostData()
#print(googlepostcommit.iloc[[400]])
googlepostcommit=googlepostcommit[0:1117]
googlepost_finished_data = settingPriority(googlepostcommit) 
googlepost_rem=googlepostcommit[googlepostcommit['Change_Request']!=0]
dispatch_queue = googlepost_rem.copy(deep = True)
dispatch_queue['Priority'] = 0.5
#googlepost_rem=googlepostcommit[201:1000]
#dispatch_queue
googlepost_rem
# Out:
#                                              Test_Suite  Change_Request Stage  \
# 546   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               1  post
# 547   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               2  post
# 548   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               2  post
# 549   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 550   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 551   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 552   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 553   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 554   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 555   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
#
# %%
googlepost_codynaqS=codynaqsingle(googlepostcommit, googlepost_finished_data,googlepost_rem,dispatch_queue)[1]

# %% [markdown]
# ### CodynaqDouble

# %%
codynaq_dispatchQ = pd.DataFrame()

def codynaqdouble(googlepostcommit, googlepost_finished,googlepost_rem):
    global codynaq_dispatchQ
    index=0
    size=googlepost_rem.Change_Request.count()
    print("Size : ",size)
    dispatchQueue=pd.DataFrame()
    while True :
        if(index<=size):
            print("Index<Size")
            if (len(dispatchQueue)==0):
                dispatchQueue=googlepost_rem[index:index+60]
                dispatch_queue = dispatchQueue.copy(deep = True)
                dispatch_queue['Priority'] = 0.5
                index=index+60
            if (len(dispatchQueue)!=0):
                result_data_frames = codynaqsingle(googlepostcommit, googlepost_finished,dispatchQueue,dispatch_queue)
                googlepost_finished = result_data_frames[0]
                temp_codynaqD = result_data_frames[1].sort_values('Priority', ascending = False)
                print(temp_codynaqD)
                codynaq_dispatchQ = codynaq_dispatchQ.append(temp_codynaqD,ignore_index = True)                
                dispatchQueue=pd.DataFrame()
            print("Index : ",index)
        else:
            break        
    return codynaq_dispatchQ

# %%
#creating history dataset for first change request and putting remaining dataset in waiting
googlepostcommit=getPostData()
googlepostcommit=googlepostcommit[0:1117]
googlepost_finished_data=settingPriority(googlepostcommit)
googlepost_rem=googlepostcommit[googlepostcommit['Change_Request']!=0]

# %%
#Calling codynaqdouble function
googlepost_codynaqdouble=codynaqdouble(googlepostcommit, googlepost_finished_data,googlepost_rem)

# %% [markdown]
# ### CodynaqFlexi

# %%
# create historical data frame
# put them into waiting queue
# assume a prioritisation window size to be 0.7
# take certatin tests from the waiting queue and put them into dispatch queue according to the condition
# reprioritize the dispatch queue continuously

codynaq_dispatchQ_F = pd.DataFrame()

def codynaqflexi(googlepostcommit, googlepost_finished,googlepost_rem):
    global codynaq_dispatchQ_F
    index=0
    size=googlepost_rem.Change_Request.count()
    print("Size : ",size)
    dispatchQueue=pd.DataFrame()
    p=0.7
    dispatchSize=round(0.7*60)
    while True :
        if(index<=size):            
            if(len(dispatchQueue)<=dispatchSize):
                print("dispatch queue length ",len(dispatchQueue))
                dispatchQueue=googlepost_rem[index:index+dispatchSize]
                dispatch_queue = dispatchQueue.copy(deep = True)
                dispatch_queue['Priority'] = 0.5
                index=index+dispatchSize            
            result_data_frames=codynaqsingle(googlepostcommit, googlepost_finished,dispatchQueue,dispatch_queue)
            googlepost_finished = result_data_frames[0]
            temp_codynaqF = result_data_frames[1].sort_values('Priority', ascending = False)
            codynaq_dispatchQ_F = codynaq_dispatchQ_F.append(temp_codynaqF,ignore_index = True)                
            dispatchQueue=pd.DataFrame()
            print("Index : ",index)
        else:
            break        
    return codynaq_dispatchQ_F

# %%
googlepostcommit=getPostData()
googlepostcommit=googlepostcommit[0:1117]
googlepost_finished_data=settingPriority(googlepostcommit)
googlepost_rem=googlepostcommit[googlepostcommit['Change_Request']!=0]
googlepost_rem
# Out:
#                                              Test_Suite  Change_Request Stage  \
# 546   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               1  post
# 547   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               2  post
# 548   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               2  post
# 549   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 550   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 551   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 552   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 553   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 554   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 555   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 556   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 557   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
#