# %% [markdown]
# # Test Re-prioritization in Continuous Testing Environment

# %% [markdown]
# ## Converting of GooglePresCleanData  to csv files

# %%
# Converting GooglePre dataset to csv format 

import csv

with open('GooglePresCleanData.out', 'r') as in_file, open('GooglePresCleanData.csv', 'w') as out_file:
    stripped = (line.strip() for line in in_file)
    splited_lines = (line.split(",") for line in stripped)
    grouped_data = zip(splited_lines)
    writer = csv.writer(out_file)
    writer.writerow(("Test_Suite","Change_Request","Stage","Status","Launch_Time","Execution_Time","Size",
            "Shard_number","Run_number","Language"))
    for singleLine in grouped_data:
        writer.writerows(singleLine)

# %% [markdown]
# ## Converting of GooglePostCleanData  to csv files

# %%
# Converting GooglePost dataset to csv format 

import csv
import itertools
with open('GooglePostCleanData.out', 'r') as in_file, open('GooglePostCleanData.csv', 'w') as out_file:
    stripped = (line.strip() for line in in_file)
    splited_lines = (line.split(",") for line in stripped)
    grouped_data = zip(splited_lines)
    writer = csv.writer(out_file)
    writer.writerow(("Test_Suite","Change_Request","Stage","Status","Launch_Time","Execution_Time","Size",
            "Shard_number","Run_number","Language"))
    for singleLine in grouped_data:
        writer.writerows(singleLine)

# %% [markdown]
# #### Displaying Datasets

# %%
# reading and storing googlepre dataset in googleprecommit variable

import numpy as np
import pandas as pd

googleprecommit=pd.read_csv('GooglePresCleanData.csv') 
googleprecommit
# Out:
#                                                 Test_Suite  Change_Request  \
# 0        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 1        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 2        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 3        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# 4        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               5
# ...                                                    ...             ...
# 1045618  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045619  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6055
# 1045620  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6056
# 1045621  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6056
# 1045622  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6056
#
#         Stage  Status              Launch_Time  Execution_Time    Size  \
# 0        pres  PASSED    2014-01-01 00:48:24.0           218.0   SMALL
# 1        pres  PASSED  2014-01-01 00:48:24.218           133.0   SMALL
# 2        pres  PASSED  2014-01-01 00:48:24.351           199.0  MEDIUM
# 3        pres  PASSED   2014-01-01 00:48:24.55           284.0   SMALL
# 4        pres  PASSED  2014-01-01 00:48:24.834           152.0   SMALL
# ...       ...     ...                      ...             ...     ...
# 1045618  pres  PASSED  2014-01-15 16:56:57.496           557.0   SMALL
# 1045619  pres  PASSED  2014-01-15 16:56:58.053          1168.0  MEDIUM
# 1045620  pres  PASSED    2014-01-15 16:57:44.0          3360.0  MEDIUM
# 1045621  pres  PASSED   2014-01-15 16:57:47.36         13824.0  MEDIUM
# 1045622  pres  PASSED  2014-01-15 16:58:01.184          3360.0  MEDIUM
#
#          Shard_number  Run_number Language
# 0                   0           0       CC
# 1                   0           0       CC
# 2                   0           0       CC
# 3                   0           0       CC
# 4                   0           0       CC
# ...               ...         ...      ...
# 1045618             0           0       CC
# 1045619             0           0       CC
# 1045620             0           0       CC
# 1045621             0           0       CC
# 1045622             0           0       CC
#
# [1045623 rows x 10 columns]

# %%
def getPostData():
    googlepostcommit=pd.read_csv('GooglePostCleanData.csv') #, delimiter=",")
    googlepostcommit
    return googlepostcommit

# %%
# reading and storing googlepost dataset in googlepostcommit variable

import numpy as np
import pandas as pd

googlepostcommit=getPostData()
googlepostcommit
# Out:
#                                                 Test_Suite  Change_Request  \
# 0        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 1        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 2        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 3        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 4        /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# ...                                                    ...             ...
# 1461298  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
# 1461299  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
# 1461300  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
# 1461301  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
# 1461302  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            6058
#
#         Stage  Status              Launch_Time  Execution_Time    Size  \
# 0        post  PASSED    2014-01-01 00:00:02.0           996.0   LARGE
# 1        post  PASSED  2014-01-01 00:00:02.996          1676.0   LARGE
# 2        post  PASSED  2014-01-01 00:00:04.672          2565.0   LARGE
# 3        post  PASSED  2014-01-01 00:00:07.237          1611.0   LARGE
# 4        post  PASSED  2014-01-01 00:00:08.848          1089.0   LARGE
# ...       ...     ...                      ...             ...     ...
# 1461298  post  PASSED  2014-01-15 16:59:52.275          9996.0   SMALL
# 1461299  post  PASSED  2014-01-15 17:00:02.271        152869.0   LARGE
# 1461300  post  PASSED   2014-01-15 17:02:35.14        407565.0   LARGE
# 1461301  post  PASSED  2014-01-15 17:09:22.705          5602.0  MEDIUM
# 1461302  post  PASSED  2014-01-15 17:09:28.307          3098.0  MEDIUM
#
#          Shard_number  Run_number Language
# 0                   0           0      WEB
# 1                   0           0      WEB
# 2                   0           0      WEB
# 3                   0           0      WEB
# 4                   0           0      WEB
# ...               ...         ...      ...
# 1461298             0           0     JAVA
# 1461299             0           0     JAVA
# 1461300             1           0     JAVA
# 1461301             0           0     JAVA
# 1461302             0           0     JAVA
#
# [1461303 rows x 10 columns]

# %% [markdown]
# ##  Analysis of  Test Requests per minute in the Pre Datasets

# %%
#Finding  Number of test requests per minute in GooglePre and calculating median and max

googleprecommit['Launch_Time'] = pd.to_datetime(googleprecommit['Launch_Time'])
preData_test_requests = googleprecommit.groupby(pd.Grouper(key='Launch_Time', freq='min'))['Test_Suite'].apply(pd.Series.nunique)

print("preData_test_requests")
print("Median: "+str(preData_test_requests.median()))
print("Maximum: "+str(preData_test_requests.max()))
# Out:
# preData_test_requests
# Median: 6.0
# Maximum: 2102

# %% [markdown]
# ##  Analysis of  Test Requests per minute in the Post Datasets

# %%
#Finding  Number of test requests per minute in GooglePost and calculating median and max

googlepostcommit['Launch_Time'] = pd.to_datetime(googlepostcommit['Launch_Time'])
postData_test_req = googlepostcommit.groupby(pd.Grouper(key='Launch_Time', freq='min'))['Test_Suite'].apply(pd.Series.nunique)

print("postData_test_req")
print("Median: "+str(postData_test_req.median()))
print("Maximum: "+str(postData_test_req.max()))
# Out:
# postData_test_req
# Median: 19.0
# Maximum: 2560

# %% [markdown]
# #### Boxplot of number of test requests submitted per minute for Google Datasets

# %%
# Box plot-Number of test requests per minute for GooglePre Dataset

import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot( y=preData_test_requests)
# Out:
# <AxesSubplot:ylabel='Test_Suite'>

# %%
# Box plot-Number of test requests per minute for GooglePost Dataset

import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot( y=postData_test_req )
# Out:
# <AxesSubplot:ylabel='Test_Suite'>

# %% [markdown]
# #### Implementation: Reprioritization Algorithm

# %% [markdown]
#  Calculate conditional probability for incoming test cases and calculate new priority score accordingly.
#
#   - Inputs (test to be reprioritized(currentTest),recently finished test from the same change request(t_finish),test execution     history,dispatch_queue)
#   - check if the test already exists in history.
#   - if no, ie it is a new test, then set its conditional failure rate to 0.5 and add it to dispatch queue
#   - if yes, find the following co failure parameters with respect to current test and recently finished test
#       + co-occurance count
#       + co-fail count
#       + t_fail , t_finish pass count
#   - if previous test status= failed
#        - new score= previous priority+ (p(current and previous test fails)- 0.5)
#   - if previous test status= pass
#       - new score= previous priority+ (p(current test fails and previous test pass)-0.5)
#   - priorirty  = previous_priority+(new score-0.5)

# %%
# define a dataset to store frequent co failing test suites
Cofailure_Distribution = pd.DataFrame(columns = ["Test Pair","Fail Together","Run Together","Pass-Fail"])

# %%
import traceback
#currentTest - test to be reprioritized
#t_finish - historial tests with same change request( To calculate co-fail data)
#finishedGpost - historical completed tests (To calculate the new priority)

def reprioritize(currentTest,index,t_finish,finishedGpost,dispatch_queue): 
    global Cofailure_Distribution
    test_names = [currentTest.Test_Suite,t_finish.Test_Suite]
    sorted_names = sorted(test_names)
    joined_names = ','.join(sorted_names)
    
    # get all change request numbers
    change_requests= googlepostcommit.Change_Request.unique() 

    # check if currentTest was executed before in the historical queue
    if (currentTest.Test_Suite in finishedGpost.Test_Suite.values):
        # initialise the co-fail count
        co_fail_count=0
        # initialise current fail , t_finish pass count
        co_fail_pass_count=0
        # initialise co_occurance count
        co_occurance_count=0

    
        # get the previous status
        previous_status=finishedGpost.iat[finishedGpost.Test_Suite.eq(currentTest.Test_Suite).idxmax(),3]
        #get the previous priority off currentTest
        previous_priority=finishedGpost.iat[finishedGpost.Test_Suite.eq(currentTest.Test_Suite).idxmax(),10] # priority column no=10
        
        # get all change requests before the current test change request .
        # Generate co fail/co occurance data of currentTest with respect to other tests in these change requests.
        previous_change_requests= sorted(i for i in change_requests if i < currentTest.Change_Request)
        
        # COFAILURE DISTRIBUTION USING CONDITIONAL PROBABILITY
        # iterate through the previous change requests
        for i in range(0, len(previous_change_requests)):
            prev_req = previous_change_requests[i]
            overlapping_row_count = googlepostcommit[googlepostcommit['Change_Request']<prev_req].shape[0]
#        for pre_req in previous_change_requests:
        
            # get all test suites in current change request being iterated
            test_suites_in_change_req=googlepostcommit[googlepostcommit['Change_Request']==prev_req]
            try:
                # check for co-occurance
                if(currentTest.Test_Suite in test_suites_in_change_req.Test_Suite.values and t_finish.Test_Suite in test_suites_in_change_req.Test_Suite.values):
                    # if yes, increment the co-occurance count
                    co_occurance_count+=1
                    test_suite_actual_index_currentTest = test_suites_in_change_req.Test_Suite.eq(currentTest.Test_Suite).idxmax()
                    test_suite_actual_index_tFinish = test_suites_in_change_req.Test_Suite.eq(t_finish.Test_Suite).idxmax()

                    current_test_previous_status=test_suites_in_change_req.iat[test_suite_actual_index_currentTest-overlapping_row_count,3]
                    # get the status of currentTest in pre_req
                    t_finish_previous_status=test_suites_in_change_req.iat[test_suite_actual_index_tFinish-overlapping_row_count,3]
                    #  current_test failed and t_finish also failed
                    if(current_test_previous_status == "FAILED" and t_finish_previous_status == "FAILED"):
                        # increment the co fail count
                        co_fail_count+=1
                        
                    # if current test failed and t_finish passed
                    if(current_test_previous_status == "FAILED" and t_finish_previous_status == "PASSED"):
                        # increment the count of fail and pass together
                        co_fail_pass_count+=1

            except:
                print("Exception Occured")
                print("Shape of test suite in change req ",test_suites_in_change_req.shape)
                traceback.print_exc()
                pass
                
            
        #Assign conditional probability score  
        conditional_prob_score=0
     
        # if both currentTest and t_finish fails
        if t_finish.Status == "FAILED":
            if co_occurance_count != 0:
                conditional_prob_score=co_fail_count/co_occurance_count
        else:
            # if currentTest fail and t_finish pass
            if co_occurance_count != 0:
                conditional_prob_score=co_fail_pass_count/co_occurance_count
                
        if(conditional_prob_score!=0):
            new_score=previous_priority+(conditional_prob_score-0.5)
            # change the priority score to new_score
            finishedGpost.loc[finishedGpost['Test_Suite'] == currentTest.Test_Suite, 'Priority'] = new_score
            dispatch_queue.at[index, 'Priority'] = new_score
        # if the current test or previous test has status as failed, change the status as failed .
        # if the test is already present in history , a new row will not be added for that test suite again.
        # So update the status of existing row.
        
        if(previous_status == "FAILED" or currentTest.Status == "FAILED"):
            finishedGpost.loc[finishedGpost['Test_Suite'] == currentTest.Test_Suite, 'Status'] = "Failed"
        return True
    # if the test case is a new test case 
    else:
        return False

# %%
# set finish  test change req number- initialization
finish_change_req_no= 0

# %%
# getFinishedTests()

# return an array of recently finsihsed tests from the test executors
import numpy as np
import pandas as pd

def getFinishTests():
    finished_tests=pd.DataFrame(googlepostcommit[googlepostcommit['Change_Request']==finish_change_req_no], columns =
                                ["Test_Suite","Change_Request","Status","Launch_Time"])
    return finished_tests

finishedTests=getFinishTests()
finishedTests
# Out:
#                                             Test_Suite  Change_Request  \
# 0    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 1    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 2    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 3    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 4    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 5    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 6    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 7    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 8    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 9    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 10   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 11   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 12   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 13   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 14   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 15   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 16   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 17   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 18   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 19   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 20   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 21   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 22   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 23   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 24   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 25   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 26   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 27   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 28   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 29   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# ..                                                 ...             ...
# 516  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 517  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 518  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 519  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 520  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 521  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 522  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 523  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 524  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 525  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 526  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 527  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 528  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 529  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 530  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 531  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 532  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 533  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 534  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 535  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 536  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 537  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 538  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 539  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 540  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 541  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 542  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 543  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 544  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
# 545  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0
#
#      Status             Launch_Time
# 0    PASSED 2014-01-01 00:00:02.000
# 1    PASSED 2014-01-01 00:00:02.996
# 2    PASSED 2014-01-01 00:00:04.672
# 3    PASSED 2014-01-01 00:00:07.237
# 4    PASSED 2014-01-01 00:00:08.848
# 5    PASSED 2014-01-01 00:00:09.937
# 6    PASSED 2014-01-01 00:00:11.345
# 7    PASSED 2014-01-01 00:00:11.386
# 8    PASSED 2014-01-01 00:00:11.896
# 9    PASSED 2014-01-01 00:00:12.143
# 10   PASSED 2014-01-01 00:00:12.590
# 11   PASSED 2014-01-01 00:00:13.672
# 12   PASSED 2014-01-01 00:00:13.772
# 13   PASSED 2014-01-01 00:00:14.293
# 14   PASSED 2014-01-01 00:00:16.541
# 15   PASSED 2014-01-01 00:00:16.908
# 16   PASSED 2014-01-01 00:00:19.528
# 17   PASSED 2014-01-01 00:00:20.179
# 18   PASSED 2014-01-01 00:00:20.218
# 19   PASSED 2014-01-01 00:00:20.403
# 20   PASSED 2014-01-01 00:00:21.566
# 21   PASSED 2014-01-01 00:00:23.006
# 22   PASSED 2014-01-01 00:00:23.915
# 23   PASSED 2014-01-01 00:00:24.015
# 24   PASSED 2014-01-01 00:00:24.129
# 25   PASSED 2014-01-01 00:00:24.275
# 26   PASSED 2014-01-01 00:00:24.418
# 27   PASSED 2014-01-01 00:00:24.554
# 28   PASSED 2014-01-01 00:00:24.647
# 29   PASSED 2014-01-01 00:00:25.895
# ..      ...                     ...
# 516  PASSED 2014-01-01 00:20:52.099
# 517  PASSED 2014-01-01 00:20:52.878
# 518  PASSED 2014-01-01 00:20:52.977
# 519  PASSED 2014-01-01 00:21:11.031
# 520  PASSED 2014-01-01 00:21:22.759
# 521  PASSED 2014-01-01 00:21:56.010
# 522  PASSED 2014-01-01 00:22:10.250
# 523  PASSED 2014-01-01 00:22:12.789
# 524  PASSED 2014-01-01 00:22:14.602
# 525  PASSED 2014-01-01 00:22:33.936
# 526  PASSED 2014-01-01 00:22:41.152
# 527  PASSED 2014-01-01 00:22:43.173
# 528  PASSED 2014-01-01 00:22:43.627
# 529  PASSED 2014-01-01 00:22:43.845
# 530  PASSED 2014-01-01 00:22:44.095
# 531  PASSED 2014-01-01 00:22:44.177
# 532  PASSED 2014-01-01 00:22:44.241
# 533  PASSED 2014-01-01 00:22:44.508
# 534  PASSED 2014-01-01 00:22:44.553
# 535  PASSED 2014-01-01 00:22:44.710
# 536  PASSED 2014-01-01 00:22:44.766
# 537  PASSED 2014-01-01 00:22:44.835
# 538  PASSED 2014-01-01 00:22:44.868
# 539  PASSED 2014-01-01 00:22:45.095
# 540  PASSED 2014-01-01 00:22:45.439
# 541  PASSED 2014-01-01 00:22:45.819
# 542  PASSED 2014-01-01 00:22:45.828
# 543  PASSED 2014-01-01 00:22:45.844
# 544  PASSED 2014-01-01 00:22:45.858
# 545  PASSED 2014-01-01 00:22:46.186
#
# [546 rows x 4 columns]

# %% [markdown]
# ## CODYNAQSINGLE algorithm
#
# + This algorithm executes tests and reprioritizes tests based on co-failure distribution

# %%
# Prorbability assigning functionality
def calculateProbabilityPassFail(status): 
    value=1
    if status=="PASSED":
        value=0.5
    return value

# %%
#Function for appending to history/finished test
def appendingToHistory(row,finishedGpost):
        priority=0.5
        finishedGpost=finishedGpost.append({'Test_Suite' : row.Test_Suite , 
                                            'Change_Request' : row.Change_Request, 
                                            'Stage':row.Stage, 'Status': row.Status, 
                                            'Launch_Time':row.Launch_Time, 
                                            'Execution_Time':row.Execution_Time, 
                                            'Size':row.size, 'Shard_number':row.Shard_number,
                                                      'Run_number':row.Run_number, 'Language':row.Language,
                                              'Priority':priority}, ignore_index=True)
        
        return finishedGpost

# %%
def addtoDispatchQueue(row,dispatch_queue):
        priority=0.5
        dispatch_queue =dispatch_queue.append({'Test_Suite' : row.Test_Suite , 
                                               'Change_Request' : row.Change_Request, 
                                                'Stage':row.Stage, 'Status': row.Status, 
                                               'Launch_Time':row.Launch_Time, 
                                                      'Execution_Time':row.Execution_Time,
                                               'Size':row.size, 'Shard_number':row.Shard_number,
                                                      'Run_number':row.Run_number, 'Language':row.Language,
                                              'Priority':priority}, ignore_index=True)
        
        return dispatch_queue

# %%
def codynaqsingle(googlepostdatas,finishedGpost,googlepost_rem,dispatch_queue):
    # iterating over waiting queue for reprioritizing the datasets
    for index, row in googlepost_rem.iterrows():
        # checking for a match whether previous test case and the current test case are from  same change request
        if googlepostdatas.loc[index, 'Change_Request'] == googlepostdatas.loc[index-1, 'Change_Request']:
            temp_test_suites_current_request= finishedGpost.loc[finishedGpost['Change_Request']==row.Change_Request] 
            # iterating over historical test cases for reprioritizing the current test case
            for index_j, row_j in temp_test_suites_current_request.iterrows():
                # temp suite can contain the same test case from historical result with same change request number
                #finishedGpost can contain the same test case from historical results with any change request
                result=reprioritize(row,index,row_j, finishedGpost,dispatch_queue)
                if(result==False):
                    finishedGpost=appendingToHistory(row,finishedGpost)
                    
        else:
            # appending test case to the finishedGpost data frame (historical)
            finishedGpost=appendingToHistory(row,finishedGpost)
            
    return [finishedGpost,dispatch_queue]

# %%
#function for assigning priority
import pandas as pd
def settingPriority(data): 
    data['Priority'] = 0.5
    return data

# %%
#seperating first change request (0) and keeping it as finished test;keeping other change request in waiting queue
googlepostcommit=getPostData()[0:3000]
googlepostcommit=settingPriority(googlepostcommit)
googlepost_finished_data = googlepostcommit[googlepostcommit["Change_Request"]==0]
googlepost_rem = googlepostcommit[googlepostcommit["Change_Request"]!=0]
dispatch_queue = googlepost_rem.copy(deep = True)
googlepost_finished_data
# Out:
#                                             Test_Suite  Change_Request Stage  \
# 0    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 1    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 2    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 3    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 4    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 5    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 6    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 7    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 8    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 9    /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 10   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 11   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 12   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 13   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 14   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 15   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 16   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 17   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 18   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 19   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 20   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 21   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 22   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 23   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 24   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 25   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 26   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 27   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 28   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 29   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# ..                                                 ...             ...   ...
# 516  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 517  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 518  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 519  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 520  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 521  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 522  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 523  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 524  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 525  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 526  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 527  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 528  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 529  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 530  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 531  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 532  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 533  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 534  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 535  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 536  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 537  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 538  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 539  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 540  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 541  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 542  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 543  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 544  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
# 545  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               0  post
#
#      Status              Launch_Time  Execution_Time    Size  Shard_number  \
# 0    PASSED    2014-01-01 00:00:02.0           996.0   LARGE             0
# 1    PASSED  2014-01-01 00:00:02.996          1676.0   LARGE             0
# 2    PASSED  2014-01-01 00:00:04.672          2565.0   LARGE             0
# 3    PASSED  2014-01-01 00:00:07.237          1611.0   LARGE             0
# 4    PASSED  2014-01-01 00:00:08.848          1089.0   LARGE             0
# 5    PASSED  2014-01-01 00:00:09.937          1408.0   SMALL             0
# 6    PASSED  2014-01-01 00:00:11.345            41.0   SMALL             0
# 7    PASSED  2014-01-01 00:00:11.386           510.0   SMALL             0
# 8    PASSED  2014-01-01 00:00:11.896           247.0  MEDIUM             0
# 9    PASSED  2014-01-01 00:00:12.143           447.0   SMALL             0
# 10   PASSED   2014-01-01 00:00:12.59          1082.0  MEDIUM             0
# 11   PASSED  2014-01-01 00:00:13.672           100.0   SMALL             0
# 12   PASSED  2014-01-01 00:00:13.772           521.0   SMALL             0
# 13   PASSED  2014-01-01 00:00:14.293          2248.0  MEDIUM             0
# 14   PASSED  2014-01-01 00:00:16.541           367.0   SMALL             0
# 15   PASSED  2014-01-01 00:00:16.908          2620.0   SMALL             0
# 544  PASSED  2014-01-01 00:22:45.858           328.0   SMALL             0
# 545  PASSED  2014-01-01 00:22:46.186           865.0  MEDIUM             0
#
#      Run_number Language  Priority
# 0             0      WEB       0.5
# 1             0      WEB       0.5
# 2             0      WEB       0.5
# 3             0      WEB       0.5
# 4             0      WEB       0.5
# 5             0       CC       0.5
# 6             0       CC       0.5
# 7             0       CC       0.5
# 8             0       CC       0.5
# 9             0       CC       0.5
# 10            0       CC       0.5
# 11            0       CC       0.5
# 12            0       CC       0.5
# 13            0       CC       0.5
# 14            0       CC       0.5
# 15            0       CC       0.5
# 16            0       CC       0.5
# 17            0       CC       0.5
# 18            0       CC       0.5
# 19            0       CC       0.5
# 20            0       SH       0.5
# 21            0       CC       0.5
# 22            0       CC       0.5
# 23            0     JAVA       0.5
# 24            0     JAVA       0.5
# 25            0     JAVA       0.5
# 26            0     JAVA       0.5
# 27            0       CC       0.5
# 28            0       PY       0.5
# 29            0       SH       0.5
# ..          ...      ...       ...
# 516           0       CC       0.5
# 517           0       CC       0.5
# 518           0       CC       0.5
# 519           0       CC       0.5
# 520           0       CC       0.5
# 521           0       CC       0.5
# 522           0       CC       0.5
# 523           0       CC       0.5
# 524           0       CC       0.5
# 525           0       CC       0.5
# 526           0       CC       0.5
# 527           0       CC       0.5
# 528           0       PY       0.5
# 529           0       CC       0.5
# 530           0       CC       0.5
# 531           0       SH       0.5
# 532           0       PY       0.5
# 533           0       PY       0.5
# 534           0       CC       0.5
# 535           0       CC       0.5
# 536           0       CC       0.5
# 537           0       PY       0.5
# 538           0       CC       0.5
# 539           0       CC       0.5
# 540           0       PY       0.5
# 541           0       GO       0.5
# 542           0       GO       0.5
# 543           0       GO       0.5
# 544           0       CC       0.5
# 545           0       SH       0.5
#
# [546 rows x 11 columns]

# %%
googlepost_codynaqS=codynaqsingle(googlepostcommit, googlepost_finished_data,googlepost_rem,dispatch_queue)[1]
# Out:
#                                              Test_Suite  Change_Request Stage  \
# 931   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 930   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 914   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 913   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 912   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 911   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 885   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 1525  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              12  post
# 884   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 2183  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2181  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2182  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 546   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               1  post
# 2180  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2185  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2186  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2187  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2188  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2189  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2190  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2191  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2184  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2179  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2193  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2169  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2162  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2163  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2164  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2165  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 2166  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# ...                                                 ...             ...   ...
# 1383  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1384  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1385  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1386  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1387  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1388  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1389  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1390  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1391  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1392  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1377  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1375  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1358  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1374  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1359  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1360  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1361  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1362  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1363  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1364  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1365  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1366  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1367  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1368  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1369  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1370  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1371  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1372  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 1373  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 2999  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
#
#       Status              Launch_Time  Execution_Time    Size  Shard_number  \
# 931   FAILED  2014-01-01 00:51:00.212          4424.0   LARGE             5
# 930   PASSED  2014-01-01 00:50:56.152          4060.0   LARGE             4
# 914   FAILED  2014-01-01 00:50:23.367          4431.0   LARGE             5
# 913   FAILED   2014-01-01 00:50:19.06          4307.0   LARGE             4
# 912   PASSED  2014-01-01 00:50:14.993          4067.0   LARGE             1
# 911   PASSED  2014-01-01 00:50:11.863          3130.0   LARGE             8
# 885   FAILED  2014-01-01 00:40:21.036         30322.0   LARGE             1
# 1525  PASSED  2014-01-01 01:04:12.473           957.0  MEDIUM             0
# 884   PASSED  2014-01-01 00:40:17.872          3164.0   LARGE             7
# 2183  PASSED  2014-01-01 01:06:07.966           183.0   SMALL             0
# 2181  PASSED  2014-01-01 01:05:54.665         13283.0   LARGE             1
# 2182  PASSED  2014-01-01 01:06:07.948            18.0   SMALL             0
# 546   PASSED    2014-01-01 00:09:36.0         38205.0   LARGE             0
#
# 1368  PASSED  2014-01-01 01:12:27.734            70.0   SMALL             0
# 1369  PASSED  2014-01-01 01:12:27.804            64.0   SMALL             0
# 1370  PASSED  2014-01-01 01:12:27.868            91.0   SMALL             0
# 1371  PASSED  2014-01-01 01:12:27.959            92.0   SMALL             0
# 1372  PASSED  2014-01-01 01:12:28.051            77.0   SMALL             0
# 1373  PASSED  2014-01-01 01:12:28.128            75.0   SMALL             0
# 2999  PASSED  2014-01-01 01:23:14.181          4563.0  MEDIUM             0
#
#       Run_number Language  Priority
# 931            0     JAVA       4.5
# 930            0     JAVA       4.0
# 914            0     JAVA       3.5
# 913            0     JAVA       3.0
# 912            0     JAVA       2.5
# 911            0     JAVA       2.0
# 885            0     JAVA       1.5
# 1525           0       CC       1.0
# 884            0     JAVA       1.0
# 2183           0       CC       0.5
# 2181           0       CC       0.5
# 2182           0       CC       0.5
# 546            0      WEB       0.5
# 2180           0       CC       0.5
# 2185           0       CC       0.5
# 2186           0       CC       0.5
# 2187           0       CC       0.5
# 2188           0       CC       0.5
# 2189           0       CC       0.5
# 2190           0       CC       0.5
# 2191           0       CC       0.5
# 2184           0       CC       0.5
# 2179           0       CC       0.5
# 2193           0       CC       0.5
# 2169           0       CC       0.5
# 2162           0       CC       0.5
# 2163           0       CC       0.5
# 2164           0       CC       0.5
# 2165           0       CC       0.5
# 2166           0       CC       0.5
# ...          ...      ...       ...
# 1383           0       PY       0.5
# 1384           0       CC       0.5
# 1385           0       CC       0.5
# 1386           0       CC       0.5
# 1387           0       CC       0.5
# 1388           0       CC       0.5
# 1389           0       SH       0.5
# 1390           0       PY       0.5
# 1391           0       CC       0.5
# 1392           0       CC       0.5
# 1377           0       CC       0.5
# 1375           0       CC       0.5
# 1358           0       CC       0.5
# 1374           0       CC       0.5
# 1359           0       CC       0.5
# 1360           0       CC       0.5
# 1361           0       PY       0.5
# 1362           0       CC       0.5
# 1363           0       CC       0.5
# 1364           0       CC       0.5
# 1365           0       CC       0.5
# 1366           0       CC       0.5
# 1367           0       CC       0.5
# 1368           0       CC       0.5
# 1369           0       CC       0.5
# 1370           0       CC       0.5
# 1371           0       CC       0.5
# 1372           0       CC       0.5
# 1373           0       CC       0.5
# 2999           0       CC       0.5
#
# [2454 rows x 11 columns]

# %% [markdown]
# #### CodynaqSingle Results

# %%
Cofailure_Distribution.to_csv('/home/vssuchetavs/Cofailure_Distribution.csv', index_label='index')

# %%
Cofailure_Distribution.sort_values('Run Together', ascending = False)
# Out:
#                                                  Test Pair  Fail Together  \
# 1119809  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1101938  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1100550  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1101917  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1002420  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1002421  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1121698  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 974786   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1116954  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1100570  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1100571  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 814847   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 974806   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 974807   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1140836  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1377327  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1116974  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1116975  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1103284  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1101937  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1103167  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1118964  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 974669   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1102038  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1100433  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1102025  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1102024  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1102023  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1102022  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 1102021  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# ...                                                    ...            ...
# 590239   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590238   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590237   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590236   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590235   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590234   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590233   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590232   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590231   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590230   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590245   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590247   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590264   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590248   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590263   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590262   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590261   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590260   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590259   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590258   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590257   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590256   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590255   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590254   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590253   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590252   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590251   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590250   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 590249   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...            0.0
# 717404   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9
PASSED  2014-01-01 01:23:14.181          4563.0  MEDIUM             0
#
#       Run_number Language  Priority
# 931            0     JAVA       4.5
# 930            0     JAVA       4.0
# 914            0     JAVA       3.5
# 913            0     JAVA       3.0
# 912            0     JAVA       2.5
# 911            0     JAVA       2.0
# 885            0     JAVA       1.5
# 1525           0       CC       1.0
# 884            0     JAVA       1.0
# 2183           0       CC       0.5
# 2181           0       CC       0.5
# 2182           0       CC       0.5
# 546            0      WEB       0.5
# 2180           0       CC       0.5
# 2185           0       CC       0.5
# 2186           0       CC       0.5
# 2187           0       CC       0.5
# 2188           0       CC       0.5
# 2189           0       CC       0.5
# 2190           0       CC       0.5
# 2191           0       CC       0.5
# 2184           0       CC       0.5
# 2179           0       CC       0.5
# 2193           0       CC       0.5
# 2169           0       CC       0.5
# 2162           0       CC       0.5
# 2163           0       CC       0.5
# 2164           0       CC       0.5
# 2165           0       CC       0.5
# 2166           0       CC       0.5
# ...          ...      ...       ...
# 1383           0       PY       0.5
# 1384           0       CC       0.5
# 1385           0       CC       0.5
# 1386           0       CC       0.5
# 1387           0       CC       0.5
# 1388           0       CC       0.5
# 1389           0       SH       0.5
# 1390           0       PY       0.5
# 1391           0       CC       0.5
# 1392           0       CC       0.5
# 1377           0       CC       0.5
# 1375           0       CC       0.5
# 1358           0       CC       0.5
# 1374           0       CC       0.5
# 1359           0       CC       0.5
# 1360           0       CC       0.5
# 1361           0       PY       0.5
# 1362           0       CC       0.5
# 1363           0       CC       0.5
# 1364           0       CC       0.5
# 1365           0       CC       0.5
# 1366           0       CC       0.5
# 1367           0       CC       0.5
# 1368           0       CC       0.5
# 1369           0       CC       0.5
# 1370           0       CC       0.5
# 1371           0       CC       0.5
# 1372           0       CC       0.5
# 1373           0       CC       0.5
# 2999           0       CC       0.5
#
# [2454 rows x 11 columns]

# %% [markdown]
# ## CODYNAQDOUBLE Algorithm

# %%
# Creating dispatch queue of window size 60
# Adding test into dispatch queue from waiting queue(googlepost_rem) until its limit is reached
# Then reprioritizing the dispatch queue and again process repeat from step 1

codynaq_dispatchQ = pd.DataFrame()

def codynaqdouble(googlepostcommit, googlepost_finished,googlepost_rem):
    global codynaq_dispatchQ
    index=0
    size=googlepost_rem.Change_Request.count()
    print("Size : ",size)
    dispatchQueue=pd.DataFrame()
    while True :
        if(index<=size):
            print("Index<Size")
            if (len(dispatchQueue)==0):
                dispatchQueue=googlepost_rem[index:index+60]
                dispatch_queue = dispatchQueue.copy(deep = True)
                dispatch_queue['Priority'] = 0.5
                index=index+60
            if (len(dispatchQueue)!=0):
                result_data_frames = codynaqsingle(googlepostcommit, googlepost_finished,dispatchQueue,dispatch_queue)
                googlepost_finished = result_data_frames[0]
                temp_codynaqD = result_data_frames[1].sort_values('Priority', ascending = False)
                codynaq_dispatchQ = codynaq_dispatchQ.append(temp_codynaqD,ignore_index = True)                
# 2973           0       CC       0.5
# 2974           0       CC       0.5
# 2975           0       CC       0.5
# 2976           0       CC       0.5
# 2977           0       CC       0.5
# 2978           0       CC       0.5
# 2979           0       CC       0.5
# 2980           0       CC       0.5
# 2981           0       CC       0.5
# 2982           0       CC       0.5
# 2983           0       CC       0.5
# 2984           0       CC       0.5
# 2985           0       CC       0.5
# 2986           0       CC       0.5
# 2987           0       CC       0.5
# 2988           0       CC       0.5
# 2989           0       CC       0.5
# 2990           0       CC       0.5
# 2991           0       CC       0.5
# 2992           0       CC       0.5
# 2993           0       CC       0.5
# 2994           0       CC       0.5
# 2995           0       CC       0.5
# 2996           0       CC       0.5
# 2997           0       CC       0.5
# 2998           0       CC       0.5
# 2999           0       CC       0.5
#
# [2454 rows x 11 columns]

# %%
googlepost_codynaqD=codynaqdouble(googlepostcommit, googlepost_finished_data,googlepost_rem)
googlepost_codynaqD.to_csv('/home/vssuchetavs/googlepost_codynaqD.csv', index_label='index')
googlepost_codynaqD.sort_values(by="Priority",ascending=False)
# Out:
#                                              Test_Suite  Change_Request Stage  \
# 360   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 361   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 362   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 363   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 364   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 365   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 300   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 960   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              12  post
# 301   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 1635  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1636  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1637  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 0     /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               1  post
# 1633  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1638  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1639  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1640  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1641  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1642  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1643  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1644  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1634  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1632  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1646  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1622  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1615  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1616  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1617  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1618  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1619  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# ...                                                 ...             ...   ...
# 837   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 838   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 839   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 840   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 841   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 842   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 843   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 844   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 845   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 846   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 831   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 829   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 812   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 828   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 813   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 814   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 815   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 816   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 817   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 818   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 819   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 820   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 821   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 822   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 823   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 824   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 825   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 826   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 827   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 2453  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
#
#       Status              Launch_Time  Execution_Time    Size  Shard_number  \
# 360   FAILED  2014-01-01 00:51:00.212          4424.0   LARGE             5
# 361   PASSED  2014-01-01 00:50:56.152          4060.0   LARGE             4
# 362   FAILED  2014-01-01 00:50:23.367          4431.0   LARGE             5
# 363   FAILED   2014-01-01 00:50:19.06          4307.0   LARGE             4
# 364   PASSED  2014-01-01 00:50:14.993          4067.0   LARGE             1
# 365   PASSED  2014-01-01 00:50:11.863          3130.0   LARGE             8
# 300   FAILED  2014-01-01 00:40:21.036         30322.0   LARGE             1
# 960   PASSED  2014-01-01 01:04:12.473           957.0  MEDIUM             0
# 301   PASSED  2014-01-01 00:40:17.872          3164.0   LARGE             7
# 1635  PASSED  2014-01-01 01:06:39.663            30.0  MEDIUM             0
# 1636  PASSED  2014-01-01 01:06:39.693           318.0   SMALL             0
# 1637  PASSED  2014-01-01 01:06:40.011            86.0  MEDIUM             0
# 0     PASSED    2014-01-01 00:09:36.0         38205.0   LARGE             0
# 1633  PASSED  2014-01-01 01:06:37.776          1882.0   LARGE             0
# 1638  PASSED  2014-01-01 01:06:40.097           275.0   SMALL             0
# 1639  PASSED  2014-01-01 01:06:40.372           216.0   SMALL             0
# 1640  PASSED  2014-01-01 01:06:40.588           126.0   SMALL             0
# 1641  PASSED  2014-01-01 01:06:40.714           458.0   SMALL             0
# 1642  PASSED  2014-01-01 01:06:41.172           636.0   LARGE             0
# 1643  PASSED  2014-01-01 01:06:41.808            22.0   SMALL             0
# 1644  PASSED   2014-01-01 01:06:41.83            28.0   SMALL             0
# 1634  PASSED  2014-01-01 01:06:39.658             5.0   SMALL             0
# 1639           0       CC       0.5
# 1640           0       CC       0.5
# 1641           0       CC       0.5
# 1642           0       CC       0.5
# 1643           0       CC       0.5
# 1644           0       CC       0.5
# 1634           0       CC       0.5
# 1632           0       CC       0.5
# 1646           0       CC       0.5
# 1622           0       CC       0.5
# 1615           0       CC       0.5
# 1616           0       CC       0.5
# 1617           0       CC       0.5
# 1618           0       CC       0.5
# 1619           0       CC       0.5
# ...          ...      ...       ...
# 837            0       CC       0.5
# 838            0       CC       0.5
# 839            0       CC       0.5
# 840            0       CC       0.5
# 841            0       CC       0.5
# 842            0       CC       0.5
# 843            0       CC       0.5
# 844            0       CC       0.5
# 845            0       CC       0.5
# 846            0       CC       0.5
# 831            0       CC       0.5
# 829            0       CC       0.5
# 812            0       PY       0.5
# 828            0       PY       0.5
# 813            0       CC       0.5
# 814            0       CC       0.5
# 815            0       CC       0.5
# 816            0       CC       0.5
# 817            0       CC       0.5
# 818            0       CC       0.5
# 819            0       CC       0.5
# 820            0       CC       0.5
# 821            0       PY       0.5
# 822            0       CC       0.5
# 823            0       CC       0.5
# 824            0       CC       0.5
# 825            0       CC       0.5
# 826            0       CC       0.5
# 827            0       PY       0.5
# 2453           0       CC       0.5
#
# [2454 rows x 11 columns]

# %% [markdown]
# ## CODYNAQFLEXI Algorithm

# %%
# Creating dispatch queue of window size 60 and threshold 0.7
# Adding test into dispatch queue from waiting queue(googlepost_rem) until its limit is reached
# Then reprioritizing the dispatch queue and again process repeat from step 1

codynaq_dispatchQ_F = pd.DataFrame()

def codynaqflexi(googlepostcommit, googlepost_finished,googlepost_rem):
    global codynaq_dispatchQ_F
    index=0
    size=googlepost_rem.Change_Request.count()
    print("Size : ",size)
    dispatchQueue=pd.DataFrame()
    p=0.7
    dispatchSize=round(0.7*60)
    while True :
        if(index<=size):            
            if(len(dispatchQueue)<=dispatchSize):
                print("dispatch queue length ",len(dispatchQueue))
                dispatchQueue=googlepost_rem[index:index+dispatchSize]
                dispatch_queue = dispatchQueue.copy(deep = True)
                dispatch_queue['Priority'] = 0.5
                index=index+dispatchSize            
            result_data_frames=codynaqsingle(googlepostcommit, googlepost_finished,dispatchQueue,dispatch_queue)
            googlepost_finished = result_data_frames[0]
            temp_codynaqF = result_data_frames[1].sort_values('Priority', ascending = False)
            codynaq_dispatchQ_F = codynaq_dispatchQ_F.append(temp_codynaqF,ignore_index = True)                
            dispatchQueue=pd.DataFrame()
            print("Index : ",index)
        else:
            break        
    return codynaq_dispatchQ_F

# %%
#seperating first change request (0) and keeping it as finished test;keeping other change request in waiting queue
googlepostcommit=getPostData()[0:3000]
googlepostcommit=settingPriority(googlepostcommit)
googlepost_finished_data = googlepostcommit[googlepostcommit["Change_Request"]==0]
googlepost_rem = googlepostcommit[googlepostcommit["Change_Request"]!=0]
dispatch_queue = googlepost_rem.copy(deep = True)
googlepost_rem
# Out:
#                                              Test_Suite  Change_Request Stage  \
# 546   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               1  post
# 547   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               2  post
# 548   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               2  post
# 549   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 550   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 551   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 552   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 553   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 554   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 555   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 556   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 557   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 558   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 559   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 560   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 561   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 562   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 563   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 564   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 565   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 566   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 567   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 568   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 569   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 570   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
#
# 2980  PASSED  2014-01-01 01:22:59.174           254.0  MEDIUM             0
# 2981  PASSED  2014-01-01 01:22:59.428            14.0   SMALL             0
# 2982  PASSED  2014-01-01 01:22:59.442            16.0   SMALL             0
# 2983  PASSED  2014-01-01 01:22:59.458            15.0   SMALL             0
# 2984  PASSED  2014-01-01 01:22:59.473             9.0  MEDIUM             0
# 2985  PASSED  2014-01-01 01:22:59.482            12.0   SMALL             0
# 2986  PASSED  2014-01-01 01:22:59.494          3313.0  MEDIUM             0
# 2987  PASSED  2014-01-01 01:23:02.807           197.0  MEDIUM             0
# 2988  PASSED  2014-01-01 01:23:03.004           189.0  MEDIUM             0
# 2989  PASSED  2014-01-01 01:23:03.193          2944.0  MEDIUM             0
# 2990  PASSED  2014-01-01 01:23:06.137           406.0  MEDIUM             0
# 2991  PASSED  2014-01-01 01:23:06.543            25.0  MEDIUM             0
# 2992  PASSED  2014-01-01 01:23:06.568          1999.0  MEDIUM             0
# 2993  PASSED  2014-01-01 01:23:08.567          2587.0  MEDIUM             0
# 2994  PASSED  2014-01-01 01:23:11.154           726.0  MEDIUM             0
# 2995  FAILED   2014-01-01 01:23:11.88          1835.0  MEDIUM             0
# 2996  PASSED  2014-01-01 01:23:13.715           212.0  MEDIUM             0
# 2997  PASSED  2014-01-01 01:23:13.927           212.0   LARGE             0
# 2998  PASSED  2014-01-01 01:23:14.139            42.0  MEDIUM             0
# 2999  PASSED  2014-01-01 01:23:14.181          4563.0  MEDIUM             0
#
#       Run_number Language  Priority
# 546            0      WEB       0.5
# 547            0       PY       0.5
# 548            0      WEB       0.5
# 549            0       CC       0.5
# 550            0       CC       0.5
# 551            0      WEB       0.5
# 552            0      WEB       0.5
# 553            0       SH       0.5
# 554            0       CC       0.5
# 555            0     JAVA       0.5
# 556            0     JAVA       0.5
# 557            0       SH       0.5
# 558            0     JAVA       0.5
# 559            0     JAVA       0.5
# 560            0     JAVA       0.5
# 561            0     JAVA       0.5
# 562            0     JAVA       0.5
# 563            0     JAVA       0.5
# 564            0       PY       0.5
# 565            0       PY       0.5
# 566            0     JAVA       0.5
# 567            0     JAVA       0.5
# 568            0     JAVA       0.5
# 569            0     JAVA       0.5
# 570            0     JAVA       0.5
# 571            0     JAVA       0.5
# 572            0     JAVA       0.5
# 573            0       CC       0.5
# 574            0       CC       0.5
# 575            0       CC       0.5
# ...          ...      ...       ...
# 2970           0       CC       0.5
# 2971           0       CC       0.5
# 2972           0       CC       0.5
# 2973           0       CC       0.5
# 2974           0       CC       0.5
# 2975           0       CC       0.5
# 2976           0       CC       0.5
# 2977           0       CC       0.5
# 2978           0       CC       0.5
# 2979           0       CC       0.5
# 2980           0       CC       0.5
# 2981           0       CC       0.5
# 2982           0       CC       0.5
# 2983           0       CC       0.5
# 2984           0       CC       0.5
# 2985           0       CC       0.5
# 2986           0       CC       0.5
# 2987           0       CC       0.5
# 2988           0       CC       0.5
# 2989           0       CC       0.5
# 2990           0       CC       0.5
# 2991           0       CC       0.5
# 2992           0       CC       0.5
# 2993           0       CC       0.5
# 2994           0       CC       0.5
# 2995           0       CC       0.5
# 2996           0       CC       0.5
# 2997           0       CC       0.5
# 2998           0       CC       0.5
# 2999           0       CC       0.5
#
# [2454 rows x 11 columns]

# %%
googlepost_codynaqF=codynaqflexi(googlepostcommit, googlepost_finished_data,googlepost_rem)
googlepost_codynaqF.to_csv('/home/vssuchetavs/googlepost_codynaqF.csv', index_label='index')
googlepost_codynaqF.sort_values(by="Priority",ascending=False)
# Out:
#                                              Test_Suite  Change_Request Stage  \
# 378   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 379   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 336   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 337   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 338   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 339   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 340   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 966   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              12  post
# 341   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               3  post
# 1637  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1638  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1639  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1635  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1640  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1641  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1642  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1643  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1644  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1645  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1646  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1647  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1648  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1636  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 0     /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...               1  post
# 1649  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1633  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1616  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1617  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1618  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# 1619  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
# ...                                                 ...             ...   ...
# 837   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 838   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 839   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 840   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 841   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 842   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 843   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 844   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 845   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 846   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 831   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 829   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 812   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 828   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 813   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 814   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 815   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 816   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 817   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 818   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 819   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 820   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 821   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 822   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 823   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 824   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 825   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 826   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 827   /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              11  post
# 2453  /e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b9...              14  post
#
#       Status              Launch_Time  Execution_Time    Size  Shard_number  \
# 378   FAILED  2014-01-01 00:51:00.212          4424.0   LARGE             5
# 379   PASSED  2014-01-01 00:50:56.152          4060.0   LARGE             4
# 336   FAILED  2014-01-01 00:50:23.367          4431.0   LARGE             5
# 337   FAILED   2014-01-01 00:50:19.06          4307.0   LARGE             4
# 338   PASSED  2014-01-01 00:50:14.993          4067.0   LARGE             1
# 339   PASSED  2014-01-01 00:50:11.863          3130.0   LARGE             8
# 340   FAILED  2014-01-01 00:40:21.036         30322.0   LARGE             1
# 966   PASSED  2014-01-01 01:04:12.473           957.0  MEDIUM             0
# 341   PASSED  2014-01-01 00:40:17.872          3164.0   LARGE             7
# 1637  PASSED  2014-01-01 01:06:07.966           183.0   SMALL             0
# 1638  PASSED  2014-01-01 01:06:08.149            46.0   SMALL             0
# 1639  PASSED  2014-01-01 01:06:40.372           216.0   SMALL             0
# 1635  PASSED  2014-01-01 01:05:36.861           508.0  MEDIUM             0
# 1640  PASSED   2014-01-01 01:06:37.71            50.0   SMALL             0
# 1641  PASSED   2014-01-01 01:06:37.76            16.0   SMALL             0
# 1642  PASSED  2014-01-01 01:06:37.776          1882.0   LARGE             0
# 1643  PASSED  2014-01-01 01:06:39.658             5.0   SMALL             0
# 1644  PASSED  2014-01-01 01:06:39.663            30.0  MEDIUM             0
# 1645  PASSED  2014-01-01 01:06:39.693           318.0   SMALL             0
# 1646  PASSED  2014-01-01 01:06:40.011            86.0  MEDIUM             0
# 1647  PASSED  2014-01-01 01:06:40.097           275.0   SMALL             0
# 1648  PASSED  2014-01-01 01:06:40.588           126.0   SMALL             0
# 1636  PASSED  2014-01-01 01:05:37.369           867.0  MEDIUM             0
# 0     PASSED    2014-01-01 00:09:36.0         38205.0   LARGE             0
# 1649  PASSED  2014-01-01 01:06:08.195            57.0   SMALL             0
# 1633  PASSED  2014-01-01 01:05:32.814          3482.0  MEDIUM             1
# 1616  PASSED  2014-01-01 01:05:44.887           545.0  MEDIUM             0
# 1617  PASSED  2014-01-01 01:05:44.376           511.0  MEDIUM             0
# 1616           0       CC       0.5
# 1617           0       CC       0.5
# 1618           0       CC       0.5
# 1619           0       CC       0.5
# ...          ...      ...       ...
# 837            0       PY       0.5
# 838            0       CC       0.5
# 839            0       CC       0.5
# 840            0       CC       0.5
# 841            0       CC       0.5
# 842            0       CC       0.5
# 843            0       CC       0.5
# 844            0       CC       0.5
# 845            0       CC       0.5
# 846            0       CC       0.5
# 831            0       CC       0.5
# 829            0       CC       0.5
# 812            0       PY       0.5
# 828            0       CC       0.5
# 813            0       CC       0.5
# 814            0       CC       0.5
# 815            0       CC       0.5
# 816            0       PY       0.5
# 817            0       CC       0.5
# 818            0       CC       0.5
# 819            0       CC       0.5
# 820            0       CC       0.5
# 821            0       CC       0.5
# 822            0       CC       0.5
# 823            0       CC       0.5
# 824            0       CC       0.5
# 825            0       CC       0.5
# 826            0       CC       0.5
# 827            0       CC       0.5
# 2453           0       CC       0.5
#
# [2454 rows x 11 columns]

# %% [markdown]
# ### First Fail , All Fail and Delayed Failures

# %%
# FInding First fail
import pandas as pd
import numpy as np


def find_first_fail_all_fail(dispatch_queue,sortColumn,sortOrder,change_request):
    first_fail_sum=0
    all_fail_sum=0
    
    if(not (sortColumn=="None")):    
        dispatch_queue=dispatch_queue.sort_values(by = sortColumn,ascending = sortOrder)
    dispatch_queue_reindexed = dispatch_queue.reset_index()
    dispatch_queue_1 = dispatch_queue_reindexed[dispatch_queue_reindexed['Change_Request'] == change_request]
    dispatch_queue_failed = dispatch_queue_1[dispatch_queue_1['Status'] == "FAILED"]
    
    #First Fail,all fail
    if(len(dispatch_queue_failed)>0):
        first_fail_index  = dispatch_queue_failed.index[0]
        all_fail_index = dispatch_queue_failed.index[-1]
        first_fail_sum = dispatch_queue_reindexed[0:first_fail_index+1]['Execution_Time'].sum()
        all_fail_sum = dispatch_queue_reindexed[0:all_fail_index+1]['Execution_Time'].sum()              
    return [first_fail_sum,all_fail_sum,dispatch_queue_failed]

# %% [markdown]
# ### First Fail and All Fail

# %% [markdown]
# #### Results - CodynaqSingle

# %%
#First fail and last fail for codynaqSingle
first_fails_S = []
all_fails_S = []
failed_indices_S = []
unique_change_requests = sorted(googlepost_codynaqS.Change_Request.unique())
for change_req in unique_change_requests:
    result=find_first_fail_all_fail(googlepost_codynaqS,"Priority",False,change_req)
    for index,row in result[2].iterrows():
        failed_indices_S.append(index)
    if(result[0]!=0):
        first_fails_S.append(result[0])
        all_fails_S.append(result[1])

print("First Fail Time per Change Request",first_fails_S)
print("All Fail time per Chnage Request",all_fails_S)
Change Requests with no failures [1,2,4,5,6,7,8,9,11,12]
# Out:
# First Fail Time per Change Request [Change request 3: 4424.0, Change request 10 :5423088.0, Change request 13: 447519.0,Change request 14 : 3509059.0]
# All Fail time per Chnage Request [Change request 3: 54741.0, Change request 10:  6424976.0,Change request 13:  12356373.0, Change request 14: 3785542.0]
# Change Requests with no failures [1,2,4,5,6,7,8,9,11,12]

# %% [markdown]
# #### Results - CodynaqDouble

# %%
#First fail and last fail for codynaqSingle
first_fails_D = []
all_fails_D = []
failed_indices_D = []
unique_change_requests = sorted(googlepost_codynaqD.Change_Request.unique())
for change_req in unique_change_requests:
    result=find_first_fail_all_fail(googlepost_codynaqD,"None",False,change_req)
    for index,row in result[2].iterrows():
        failed_indices_D.append(index)
    if(result[0]!=0):
        first_fails_D.append(result[0])
        all_fails_D.append(result[1])

print("First Fail Time per Change Request",first_fails_D)
print("All Fail time per Chnage Request",all_fails_D)
# Out:
# First Fail Time per Change Request [Change request 3 : 1239582.0, Change request 10: 2786759.0, Change request 13: 7309632.0, Change request 14 :13753272.0]
# All Fail time per Chnage Request [Change request 3 : 1888768.0, Change request 10: 3811734.0, Change request 13:  13421120.0, Change request 14 : 14911990.0]
# Change Requests with no failures [1,2,4,5,6,7,8,9,11,12]

# %% [markdown]
# #### Results - CodynaqFlexi

# %%
#First fail and last fail for codynaqSingle
first_fails_F = []
all_fails_F = []
failed_indices_F = []
unique_change_requests = sorted(googlepost_codynaqF.Change_Request.unique())
for change_req in unique_change_requests:
    result=find_first_fail_all_fail(googlepost_codynaqF,"None",False,change_req)
    for index,row in result[2].iterrows():
        failed_indices_F.append(index)
    if(result[0]!=0):
        first_fails_F.append(result[0])
        all_fails_F.append(result[1])

temp = failed_indices_F
failed_indices_F = failed_indices_S
failed_indices_S = temp
    
print("First Fail Time per Change Request",first_fails_F)
print("All Fail time per Chnage Request",all_fails_F)
# Out:
# First Fail Time per Change Request [Change request 3 : 1296301.0, Change request 10: 2937764.0, Change request 13 :6671712.0, Change request 14: 13740330.0]
# All Fail time per Chnage Request [Change request 3: 1923117.0, Change request 10 : 3760740.0, Change request 13: 13725661.0, Change request 14: 14912468.0]
# Change Requests with no failures [1,2,4,5,6,7,8,9,11,12]

# %% [markdown]
# #### Results - FifoBaseline

# %%
#First fail and last fail for FIFOBaseline
first_fails_FIFO = []
all_fails_FIFO = []
failed_indices_FIFO = []
unique_change_requests = sorted(googlepost_rem.Change_Request.unique())
for change_req in unique_change_requests:
    result=find_first_fail_all_fail(googlepost_rem,"None",False,change_req)
    for index,row in result[2].iterrows():
        failed_indices_FIFO.append(index)
    if(result[0]!=0):
        first_fails_FIFO.append(result[0])
        all_fails_FIFO.append(result[1])

print("First Fail Time per Change Request",first_fails_FIFO)
print("All Fail time per Chnage Request",all_fails_FIFO)
# Out:
# First Fail Time per Change Request [1325541.0, 3639925.0, 6724175.0, 13729514.0]
# All Fail time per Chnage Request [1938819.0, 3817009.0, 13723694.0, 14924409.0]

# %% [markdown]
# ### Relative Gain in First Fail and All Fail

# %%
#G_codynaqS
import statistics

relative_gain_first_fail_S = list(map(lambda x,y:((x-y)/x)*100,first_fails_FIFO,first_fails_S))
relative_gain_all_fail_S = list(map(lambda x,y:((x-y)/x)*100,all_fails_FIFO,all_fails_S))

print("CodynaQSingle First Fail Gain - Relative",(relative_gain_first_fail_S))
print("CodynaQSingle All Fail Gain - Relative",(relative_gain_all_fail_S))
print()
print("CodynaQSingle First Fail Gain - Median",statistics.median(relative_gain_first_fail_S))
print("CodynaQSingle All Fail Gain - Median",statistics.median(relative_gain_all_fail_S))
# Out:
# CodynaQSingle First Fail Gain - Relative [99.66624947851481, -48.98900389431101, 93.34462592065198, 74.44149151965613]
# CodynaQSingle All Fail Gain - Relative [97.17658017586996, -68.32488474614547, 9.963213985971999, 74.63523011195954]
#
# CodynaQSingle First Fail Gain - Median 83.89305872015404
# CodynaQSingle All Fail Gain - Median 42.299222048965774

# %%
#G_codynaqD
import statistics

relative_gain_first_fail_D = list(map(lambda x,y:((x-y)/x)*100,first_fails_FIFO,first_fails_D))
relative_gain_all_fail_D = list(map(lambda x,y:((x-y)/x)*100,all_fails_FIFO,all_fails_D))

print("CodynaqDouble First Fail Gain - Relative",(relative_gain_first_fail_D))
print("CodynaqDouble All Fail Gain - Relative",(relative_gain_all_fail_D))
print()
print("CodynaqDouble First Fail Gain - Median",statistics.median(relative_gain_first_fail_D))
print("CodynaqDouble All Fail Gain - Median",statistics.median(relative_gain_all_fail_D))
# Out:
# CodynaqDouble First Fail Gain - Relative [6.4848239322661465, 23.439109322307466, -8.706748411515166, -0.17304327014051626]
# CodynaqDouble All Fail Gain - Relative [2.5815199871674457, 0.13819721148155534, 2.204756241286056, 0.08321267528918566]
#
# CodynaqDouble First Fail Gain - Median 3.1558903310628152
# CodynaqDouble All Fail Gain - Median 1.1714767263838057

# %%
#G_codynaqF
import statistics

relative_gain_first_fail_F = list(map(lambda x,y:((x-y)/x)*100,first_fails_FIFO,first_fails_F))
relative_gain_all_fail_F = list(map(lambda x,y:((x-y)/x)*100,all_fails_FIFO,all_fails_F))

print("CodynaqFlexi First Fail Gain - Relative",(relative_gain_first_fail_F))
print("CodynaqFlexi All Fail Gain - Relative",(relative_gain_all_fail_F))
print()
print("CodynaqFlexi First Fail Gain - Median",statistics.median(relative_gain_first_fail_F))
print("CodynaqFlexi All Fail Gain - Median",statistics.median(relative_gain_all_fail_F))
# Out:
# CodynaqFlexi First Fail Gain - Relative [2.2058917830531084, 19.290534832448472, 0.7802146731755196, -0.07877919058169137]
# CodynaqFlexi All Fail Gain - Relative [0.8098744648159524, 1.4741647190247653, -0.014332875682013893, 0.08000986839746888]
#
# CodynaqFlexi First Fail Gain - Median 1.493053228114314
# CodynaqFlexi All Fail Gain - Median 0.4449421666067106

# %% [markdown]
# ### Percentage of delayed failures

# %%
count_S = 0
count_D = 0
count_F = 0

for i in range(0,len(failed_indices_S)):
    if(failed_indices_S[i]>failed_indices_FIFO[i]):
        count_S = count_S + 1
    if(failed_indices_D[i]>failed_indices_FIFO[i]):
        count_D = count_D + 1
    if(failed_indices_F[i]>failed_indices_FIFO[i]):
        count_F = count_F + 1
               
percentage_S = count_S/len(failed_indices_FIFO)
print("Delayed failure percentage for codynaqSingle ",percentage_S)

percentage_D = count_D/len(failed_indices_FIFO)
print("Delayed failure percentage for codynaqDouble ",percentage_D)

percentage_F = count_F/len(failed_indices_FIFO)
print("Delayed failure percentage for codynaqFlexi ",percentage_F)
# Out:
# Delayed failure percentage for codynaqSingle  0.6129032258064516
# Delayed failure percentage for codynaqDouble  0.3870967741935484
# Delayed failure percentage for codynaqFlexi  0.1935483870967742
